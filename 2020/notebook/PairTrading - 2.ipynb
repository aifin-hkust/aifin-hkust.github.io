# %% [markdown]
# <center>
#     <br />
#     <h1>MAFS6010U Tutorial: Pair Trading via Cointegration</h1>
#     <br /><br />
#     Weizhi Zhu (wzhuai@connect.ust.hk)
# </center>

# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

from statsmodels.tsa.stattools import coint

import yfinance as yf

# %% [markdown]
# # Set Up Universe and Fetch Daily Price from Yahoo Finance

# %%
UNIVERSE = ["AAPL", "MSFT", "GOOG", "FB", "IXN"]
#UNIVERSE = ["PEP", "KO"]
#UNIVERSE = ["BA", "AIR"]
#UNIVERSE = ["IXN", "AAPL"]
START = "2015-03-20"; END = "2019-03-20"

tickers = yf.Tickers(" ".join(UNIVERSE))
df = tickers.history(start=START, end=END)["Close"]
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
fig, ax = plt.subplots(figsize=(20,10))
for ticker in UNIVERSE:
    ax.plot( df[ticker]/df[ticker].iloc[0], label=ticker )
ax.legend()
plt.show()

# %% [markdown]
# ## Pair Selection via Augemented Dickey-Fuller Test

# %% [markdown]
# `Cointegration`
# ![coint](figure/1.png)

# %% [markdown]
# `Stationarity and Unit root`
# ![stationarity](figure/2.png)

# %% [markdown]
# `Augmented Dickey-Fuller Test`
# ![adf](figure/3.png)

# %%
def getPair( df, critic=.05 ):
    opt_pair = []
    opt_pval = critic
    for i in range(len(UNIVERSE)):
        for j in range(i+1, len(UNIVERSE)):
            pval = coint( df[UNIVERSE[i]], df[UNIVERSE[j]] )[1]
            if pval < opt_pval:
                opt_pval = pval
                opt_pair = [UNIVERSE[i], UNIVERSE[j]]
            print( "pval of ADF test on {} and {} is {:.4f}".format(
                    UNIVERSE[i], UNIVERSE[j], pval) )
    return opt_pair, opt_pval

# %% [markdown]
# ## Portfolio, Signal and Strategy Module

# %%
## Hard-code Parameters
TSRATE = 0.000 ## transaction rate 0.05%
LEVERAGE = 1. ## leverage of a margin account.
THRESH_FACTOR = 1. ## How many times of std would be used as threshold
BURNIN = 60 ## Training period and Burn-In period. BurnIn would be used to do pair-selection, model parameter tuning, threshold tuning, and so on.\

# model parameters
TRAIN = 60 ## linear regression
DELTA = 1e-3; GAMMA = 1e-3 ## kalman filter

# %%
## Portfolio and operations
class Portfolio( object ):
    def __init__( self, cash):
        self.position = np.zeros(2)
        self.cash = cash
        self.leverage = LEVERAGE
        self.buypow = self.cash * self.leverage
        self.status = 0
    
    def _calcQty( self, weight, priceVec ):
        return self.buypow / np.dot(np.abs(weight), priceVec)
    
    def _close( self, priceVec ):
        assert self.status in [-1, 1]
        self.cash += np.dot( self.position, priceVec ) 
        self.buypow = self.cash * self.leverage
        self.position = np.zeros(2)
        self.status = 0
    
    def _execute( self, weight, priceVec, direction ):
        qty = self._calcQty( weight, priceVec )
        self.position += qty * np.array(weight) * float(direction)
        tsCost = np.dot(np.abs(weight), priceVec) * qty * TSRATE
        self.cash -= np.dot(weight, priceVec) * qty * direction + tsCost
        self.buypow -= np.dot(np.abs(weight), priceVec) * qty
        self.status = direction
    
    def execute( self, signal ):
        if signal.direction == 0:
            self._close( signal.priceVec )
        else:
            self._execute( signal.weight, signal.priceVec, signal.direction )
            
    def getValue( self, priceVec ):
        return np.dot( self.position, priceVec ) + self.cash
        
        
## sanity check
pf1 = Portfolio( 10 )
pf1.getValue( [1, 2] )
pf1._calcQty( weight=[1, -1], priceVec=[2,2] )
pf1._execute( weight=[1, -1], priceVec=[2,2], direction=-1 )
print( "Cash {}, Position {}, BuyPower {}, Status {}".format( pf1.cash, pf1.position, pf1.buypow, pf1.status ) )
pf1._close( [1, 3] )
print( "Cash {}, Position {}, BuyPower {}, Status {}".format( pf1.cash, pf1.position, pf1.buypow, pf1.status ) )
# Out:
# Cash 10.0, Position [-2.5  2.5], BuyPower 0.0, Status -1
# Cash 15.0, Position [0. 0.], BuyPower 15.0, Status 0

# %%
## signal and signal sequence module.

class Signal( object ):

    def __init__( self, weight, direction, priceVec, time=None ):
        self.weight = weight
        self.direction = direction # 1 for long, -1 for short, 0 for close
        self.priceVec = priceVec
        self.time = time
        
class SignalSequence( object ):
    
    def __init__( self ):
        self.seq = {} # time -> list of signal
        self.status = 0 # 1 for long position, -1 for short position, 0 for no position
        
    def _addSignal( self, sig ):
        if sig.time in self.seq:
            self.seq[sig.time].append( sig )
        else:
            self.seq[sig.time] = [ sig ]
            
    def addSignal( self, weight, spread, threshold, priceVec, time ):
        
        if self.status * spread > 0:
            self._addSignal( Signal( weight, 0, priceVec, time) )
            self.status = 0
        
        if not self.status:
            if spread > threshold:
                self._addSignal( Signal( weight, -1, priceVec, time ) )
                self.status = -1
            elif spread < -threshold:
                self._addSignal( Signal( weight, 1, priceVec, time ) )
                self.status = 1
    
    def mapdirection( self, direction ):
        if direction == 0:
            return "close"
        if direction == 1:
            return "long"
        if direction == -1:
            return "short"
    
    def printSignal( self ):
        if not self.seq:
            print( "No trade is done." )
            return
        for time in sorted(self.seq.keys()):
            for sig in self.seq[time]:
                print( "At {}, {} portfolio ({:.4f}Stock1 + Stock2)".format(
                    sig.time, self.mapdirection(sig.direction), sig.weight[0], sig.weight[1]) )
            
seq = SignalSequence()
seq.addSignal( weight=[1,-1], spread=.5, threshold=.2, priceVec=[2,4], time="DAY-1")
seq.addSignal( weight=[.5,1.2], spread=-0.25, threshold=.2, priceVec=[2,2], time="DAY-2")
seq.addSignal( weight=[.5,1.2], spread=.1, threshold=.2, priceVec=[2.3,2], time="DAY-3")
seq.printSignal()
# Out:
# At DAY-1, short portfolio (1.0000Stock1 + Stock2)
# At DAY-2, close portfolio (0.5000Stock1 + Stock2)
# At DAY-2, long portfolio (0.5000Stock1 + Stock2)
# At DAY-3, close portfolio (0.5000Stock1 + Stock2)

# %%
def summaryFromAccPNL( accPNL, factor = 252 ):
    '''accPNL should begin from 0. factor counts the number of trading days
    ref: https://quant.stackexchange.com/questions/39839/how-to-calculate-sharpe-ratio-from-returns '''
    df = pd.Series( accPNL )
    dailyRet = df.pct_change()
    dailyVol    = np.std( dailyRet )

    TotRet = ( accPNL[-1] - accPNL[0] ) / accPNL[0]

    dailyRet.fillna(0.0, inplace=True)
    dailyRet.replace([np.inf, -np.inf, np.nan], 0.0, inplace=True)
    if (dailyRet.mean() == 0) and (dailyRet.std == 0):
        sharpe = 0
    else:
        sharpe = np.sqrt(factor) * dailyRet.mean() / dailyRet.std()
    return dailyVol, TotRet, sharpe

# %%
## trading strategy module
from sklearn.linear_model import LinearRegression
class PairTradingStratBase( object ):
    
    def __init__(self):
        self.sigseq = SignalSequence()
        self.portfolio = Portfolio( cash=10000 )
        self.model_params = { "train_samples":TRAIN }
        
    def model( self, burnInMode, ttidx=None, train_samples=None ):
        '''
        Input: df_tr(pd.DataFrame), price training dataframe (N1, 2)
               df_te(pd.DataFrame), price testing dataframe (N2, 2)
        Return: weight(list), weights for two securities (2,)
                df_spread(pd.Series), spread on df_te (N2,)
        This method could be overriden for other models. Default is the linear regression model.
        '''
        reg = LinearRegression()
        if burnInMode:
            reg.fit( self.price_df.iloc[:BURNIN, [0]], 
                     self.price_df.iloc[:BURNIN, 1] )
            df_spread = self.price_df.iloc[:BURNIN,1] - reg.predict( self.price_df.iloc[:BURNIN,[0]] )
            return _, df_spread
        reg.fit( self.price_df.iloc[(ttidx-TRAIN):ttidx, [0]],
                 self.price_df.iloc[(ttidx-TRAIN):ttidx, 1] )
        weight = [-reg.coef_[0], 1.]
        df_spread = self.price_df.iloc[[ttidx],1] - reg.predict( self.price_df.iloc[[ttidx],[0]] )

        return weight, df_spread
            
    
    def getSignal( self, df ):
        
        ## pair-selection
        opt_pair, opt_pval = getPair( df.iloc[:BURNIN] )
        if opt_pair:
            print( "Select Pair {} and {} with p-val {:.4f}".format(opt_pair[0], opt_pair[1], opt_pval) )
            self.price_df = df[opt_pair]
        else:
            print( "No pair pass stationarity testing, use default pair {} and {}".format(UNIVERSE[0], UNIVERSE[1]) )
            self.price_df = df[[UNIVERSE[0], UNIVERSE[1]]]
        
        ## Run model on BurnIn period
        _, self.spread_df = self.model( burnInMode=True )
        threshold = THRESH_FACTOR * self.spread_df.std()
        
        ## Run model on testing period and archive signals         
        for idx, tt in enumerate( self.price_df.index[BURNIN: len(self.price_df)], BURNIN ):
            weight, spread = self.model( burnInMode=False, ttidx=idx, **self.model_params )
            self.sigseq.addSignal( weight, 
                                   spread[tt], 
                                   threshold, 
                                   self.price_df.loc[tt].to_list(), 
                                   tt.strftime("%Y-%m-%d") )
            self.spread_df[tt] = spread[tt] 
            threshold = THRESH_FACTOR * self.spread_df.iloc[-BURNIN:].std() 
        self.sigseq.printSignal()
        
    def runPortfolio( self ):
        self.accVal = pd.Series(dtype=float)
        for tt in self.price_df.index[BURNIN:]:
            if tt.strftime("%Y-%m-%d") in self.sigseq.seq.keys():
                for sig in self.sigseq.seq[tt.strftime("%Y-%m-%d")]:
                    self.portfolio.execute( sig )
            self.accVal[tt] = self.portfolio.getValue( self.price_df.loc[tt] )
        
        self.dailyVol, self.totRet, self.sharpe = summaryFromAccPNL( self.accVal )
        print( "DailyVol {:.4f}, totRet {:.4f}, sharpe {:.4f}".format(self.dailyVol, self.totRet, self.sharpe) )

# %%
stratobj = PairTradingStratBase()
stratobj.getSignal( df )
stratobj.runPortfolio()
# Out:
# pval of ADF test on AAPL and MSFT is 0.0405
# pval of ADF test on AAPL and GOOG is 0.2418
# pval of ADF test on AAPL and FB is 0.1264
# pval of ADF test on AAPL and IXN is 0.0151
# pval of ADF test on MSFT and GOOG is 0.7828
# pval of ADF test on MSFT and FB is 0.1491
# pval of ADF test on MSFT and IXN is 0.2642
# pval of ADF test on GOOG and FB is 0.1090
# pval of ADF test on GOOG and IXN is 0.1950
# pval of ADF test on FB and IXN is 0.1466
# Select Pair AAPL and IXN with p-val 0.0151
# At 2015-06-22, short portfolio (-0.5546Stock1 + Stock2)
# At 2015-06-26, close portfolio (-0.5358Stock1 + Stock2)
# At 2015-06-29, long portfolio (-0.5248Stock1 + Stock2)
# At 2015-07-09, close portfolio (-0.6330Stock1 + Stock2)
# At 2015-07-15, long portfolio (-0.6409Stock1 + Stock2)
# At 2015-07-22, close portfolio (-0.6190Stock1 + Stock2)
# At 2015-07-22, short portfolio (-0.6190Stock1 + Stock2)
# At 2015-08-20, close portfolio (-0.2685Stock1 + Stock2)
# At 2015-08-20, long portfolio (-0.2685Stock1 + Stock2)
# At 2015-09-17, close portfolio (-0.4420Stock1 + Stock2)
# At 2015-09-22, long portfolio (-0.4375Stock1 + Stock2)
# At 2015-10-02, close portfolio (-0.5076Stock1 + Stock2)
# At 2015-10-05, short portfolio (-0.5068Stock1 + Stock2)
# At 2016-01-06, close portfolio (-0.2907Stock1 + Stock2)
# At 2016-01-07, long portfolio (-0.2919Stock1 + Stock2)
# At 2016-01-28, close portfolio (-0.4611Stock1 + Stock2)
# At 2016-02-08, long portfolio (-0.4792Stock1 + Stock2)
# At 2016-02-18, close portfolio (-0.5351Stock1 + Stock2)
# At 2016-04-04, long portfolio (-0.8017Stock1 + Stock2)
# At 2016-04-15, close portfolio (-0.7251Stock1 + Stock2)
# At 2016-04-18, short portfolio (-0.7204Stock1 + Stock2)
# At 2016-06-24, close portfolio (-0.2517Stock1 + Stock2)
# At 2016-06-27, long portfolio (-0.2552Stock1 + Stock2)
# At 2016-06-29, close portfolio (-0.2720Stock1 + Stock2)
# At 2016-07-08, short portfolio (-0.3360Stock1 + Stock2)
# At 2016-07-28, close portfolio (-0.9279Stock1 + Stock2)
# At 2016-09-08, short portfolio (-0.7670Stock1 + Stock2)
# At 2016-09-13, close portfolio (-0.7584Stock1 + Stock2)
# At 2016-09-14, long portfolio (-0.7492Stock1 + Stock2)
# At 2016-09-27, close portfolio (-0.5646Stock1 + Stock2)
# At 2016-10-13, long portfolio (-0.3934Stock1 + Stock2)
# At 2016-10-21, close portfolio (-0.3123Stock1 + Stock2)
# At 2016-11-04, long portfolio (-0.2455Stock1 + Stock2)
# At 2016-11-07, close portfolio (-0.2473Stock1 + Stock2)
# At 2016-11-14, long portfolio (-0.2370Stock1 + Stock2)
# At 2016-11-17, close portfolio (-0.2482Stock1 + Stock2)
# At 2016-12-01, long portfolio (-0.2522Stock1 + Stock2)
# At 2016-12-07, close portfolio (-0.3064Stock1 + Stock2)
# At 2016-12-07, short portfolio (-0.3064Stock1 + Stock2)
# At 2016-12-28, close portfolio (-0.3674Stock1 + Stock2)
# At 2017-01-05, short portfolio (-0.3770Stock1 + Stock2)
# At 2017-02-01, close portfolio (-0.6088Stock1 + Stock2)
# At 2017-02-01, long portfolio (-0.6088Stock1 + Stock2)
# At 2017-02-21, close portfolio (-0.4449Stock1 + Stock2)
# At 2017-03-16, short portfolio (-0.4254Stock1 + Stock2)
# At 2017-04-10, close portfolio (-0.4088Stock1 + Stock2)
# At 2017-04-24, short portfolio (-0.4201Stock1 + Stock2)
# At 2017-05-08, close portfolio (-0.7195Stock1 + Stock2)
# At 2017-05-08, long portfolio (-0.7195Stock1 + Stock2)
# At 2017-05-16, close portfolio (-0.6455Stock1 + Stock2)
# At 2017-05-24, short portfolio (-0.6530Stock1 + Stock2)
# At 2017-08-10, close portfolio (-0.3308Stock1 + Stock2)
# At 2017-09-12, short portfolio (-0.3744Stock1 + Stock2)
# At 2017-11-30, close portfolio (-0.6686Stock1 + Stock2)
# At 2017-12-04, long portfolio (-0.6610Stock1 + Stock2)
# At 2017-12-08, close portfolio (-0.6302Stock1 + Stock2)
# At 2018-01-04, short portfolio (-0.5008Stock1 + Stock2)
# At 2018-02-08, close portfolio (-0.2796Stock1 + Stock2)
# At 2018-02-15, short portfolio (-0.3233Stock1 + Stock2)
# At 2018-03-22, close portfolio (-0.5492Stock1 + Stock2)
# At 2018-03-28, long portfolio (-0.5521Stock1 + Stock2)
# At 2018-04-20, close portfolio (-0.5807Stock1 + Stock2)
# At 2018-05-02, long portfolio (-0.6312Stock1 + Stock2)
# At 2018-05-31, close portfolio (-0.4342Stock1 + Stock2)
# At 2018-06-13, short portfolio (-0.4741Stock1 + Stock2)
# At 2018-06-25, close portfolio (-0.5155Stock1 + Stock2)
# At 2018-06-27, long portfolio (-0.5118Stock1 + Stock2)
# At 2018-07-06, close portfolio (-0.4743Stock1 + Stock2)
# At 2018-07-17, short portfolio (-0.4770Stock1 + Stock2)
# At 2018-07-27, close portfolio (-0.8522Stock1 + Stock2)
# At 2018-07-30, long portfolio (-0.8754Stock1 + Stock2)
# At 2018-08-24, close portfolio (-0.1264Stock1 + Stock2)
# At 2018-08-29, short portfolio (-0.1470Stock1 + Stock2)
# At 2018-09-05, close portfolio (-0.1725Stock1 + Stock2)
# At 2018-09-07, long portfolio (-0.1630Stock1 + Stock2)
# At 2018-09-20, close portfolio (-0.1527Stock1 + Stock2)
# At 2018-10-05, long portfolio (-0.1088Stock1 + Stock2)
# At 2018-11-06, close portfolio (-0.5642Stock1 + Stock2)
# At 2018-11-28, short portfolio (-0.4299Stock1 + Stock2)
# At 2018-12-17, close portfolio (-0.3266Stock1 + Stock2)
# At 2018-12-24, long portfolio (-0.3217Stock1 + Stock2)
# At 2019-01-04, close portfolio (-0.2929Stock1 + Stock2)
# At 2019-01-18, short portfolio (-0.2574Stock1 + Stock2)
# At 2019-03-11, close portfolio (-0.7634Stock1 + Stock2)
# DailyVol 0.0051, totRet 0.0954, sharpe 0.3376

# %% [markdown]
# ## Visualization

# %%
import datetime

# %%
fig, ax = plt.subplots( figsize=(20, 10) )
ax.plot( stratobj.price_df.index[BURNIN:], stratobj.spread_df[BURNIN:] )
ax.set_title( " Daily Vol {:.2f}%, TotRet {:.2f}%, Sharpe {:.2f}".format(
               stratobj.dailyVol*100, stratobj.totRet*100, stratobj.sharpe ),
               fontsize=20 )
direction = []; timeline = []; spread = []; accVal = []
for tt, sigs in stratobj.sigseq.seq.items():
    for sig in sigs:
        timeline.append( datetime.datetime.strptime(tt, "%Y-%m-%d") )
        direction.append( sig.direction )
        spread.append( stratobj.spread_df[tt] )
        accVal.append( stratobj.accVal[tt] )
for idx, action in enumerate(direction):
    if action == 0:
        direction[idx] = - direction[idx-1]
        
ax.scatter(np.array(timeline)[np.array(direction) == 1],
           np.array(spread)[np.array(direction) == 1] ,
           c='g', marker="^", label="BuySignal", s=100)
ax.scatter(np.array(timeline)[np.array(direction) == -1],
           np.array(spread)[np.array(direction) == -1],
           c='r', marker="^", label="SellSignal", s=100)
ax.legend()

fig, ax = plt.subplots( figsize=(20, 10) )
ax.plot( stratobj.price_df.index[BURNIN:], stratobj.accVal/stratobj.accVal.iloc[0] )
ax.scatter(np.array(timeline)[np.array(direction) == 1],
           np.array(accVal/stratobj.accVal.iloc[0])[np.array(direction) == 1],
           c='g', marker="^", label="BuySignal", s=100)
ax.scatter(np.array(timeline)[np.array(direction) == -1],
           np.array(accVal/stratobj.accVal.iloc[0])[np.array(direction) == -1],
           c='r', marker="^", label="SellSignal", s=100)

ax.set_title( " Daily Vol {:.2f}%, TotRet {:.2f}%, Sharpe {:.2f}".format(
               stratobj.dailyVol*100, stratobj.totRet*100, stratobj.sharpe ),
               fontsize=20 )
ax.legend()
plt.show()

# %% [markdown]
# ## Kalman Filter

# %% [markdown]
# `Kalman Filter`
# ![Kalman](figure/4.png)
# ![Training](figure/5.png)

# %% [markdown]
# * Remark: Performance of Kalman Filter is heavily dependent on the choice of hyper-parameter.

# %%
## trading strategy module
'''
Consider Kalman Filter,
\w_{k+1} = \w_k + _k, u_k\sim Normal(0, Q),
\y_k = x_k\w_k + v_k, v_k\sim Normal(0, R),
where
trainsition cov: Q = I2 * delta / (1 - delta),
observation variance: R = gamma.
'''
DELTA = 1e-5
DELTA2 = .1
GAMMA = 1.
THRESH_FACTOR = 1. 
BURNIN = 30

from pykalman import KalmanFilter
class KFStrat( PairTradingStratBase ):
    
    def __init__( self ):
        super(KFStrat, self).__init__()
        self.kf = None
        self.model_params = { "delta_1":DELTA,
                              "delta_2":DELTA2,
                              "gamma":GAMMA }
    
    def model( self, burnInMode=True, ttidx=None, delta_1=DELTA, delta_2=DELTA2, gamma=GAMMA ):
        ## override model method 
        covQ = np.array([delta_1/(1.-delta_1), delta_2/(1-delta_2)]) * np.eye(2)
        varR = gamma
        if burnInMode:
            ## build kf model from training data
            obsMat = np.vstack( (self.price_df.iloc[:BURNIN,0].to_numpy(), 
                                 np.ones(BURNIN)) ).T.reshape(-1,1,2)
            obsVec = self.price_df.iloc[:BURNIN,1].to_numpy().reshape(-1, 1)
            self.kf = KalmanFilter( n_dim_obs=1,
                                    n_dim_state=2,
                                    initial_state_mean=np.zeros(2),
                                    initial_state_covariance=np.ones((2, 2)),
                                    transition_matrices=np.eye(2),
                                    observation_matrices=obsMat,
                                    observation_covariance=varR,
                                    transition_covariance=covQ )
            
            w_kf, cov_kf = self.kf.filter( obsVec )
            assert len(w_kf) == BURNIN
            df_spread = self.price_df.iloc[:BURNIN,1] - w_kf[:,0]*self.price_df.iloc[:BURNIN,0] - w_kf[:,1]
            self.w_kf, self.cov_kf = w_kf[-1], cov_kf[-1] 
            return _, df_spread
        
        ## update kalman fiter and return weight
        assert self.kf is not None
        self.w_kf, self.cov_kf = self.kf.filter_update(
                        filtered_state_mean = self.w_kf,
                        filtered_state_covariance = self.cov_kf,
                        observation = self.price_df.iloc[ttidx, 1],
                        observation_matrix = np.array( [self.price_df.iloc[ttidx, 0], 1] ).reshape(1, 2) )
     
        weight = [-self.w_kf[0], 1.]
        df_spread = self.price_df.iloc[[ttidx],1] - self.w_kf[0]*self.price_df.iloc[[ttidx],0] - self.w_kf[1]

        return weight, df_spread

# %%
stratobj = KFStrat()
stratobj.getSignal( df )
stratobj.runPortfolio()
# Out:
# pval of ADF test on AAPL and MSFT is 0.2631
# pval of ADF test on AAPL and GOOG is 0.4818
# pval of ADF test on AAPL and FB is 0.3793
# pval of ADF test on AAPL and IXN is 0.0523
# pval of ADF test on MSFT and GOOG is 1.0000
# pval of ADF test on MSFT and FB is 0.6279
# pval of ADF test on MSFT and IXN is 0.9157
# pval of ADF test on GOOG and FB is 0.6051
# pval of ADF test on GOOG and IXN is 0.7182
# pval of ADF test on FB and IXN is 0.6150
# No pair pass stationarity testing, use default pair AAPL and MSFT
# At 2015-05-22, long portfolio (-0.3394Stock1 + Stock2)
# At 2015-05-27, close portfolio (-0.3393Stock1 + Stock2)
# At 2015-06-18, short portfolio (-0.3404Stock1 + Stock2)
# At 2015-06-22, close portfolio (-0.3406Stock1 + Stock2)
# At 2015-06-24, long portfolio (-0.3390Stock1 + Stock2)
# At 2015-07-08, close portfolio (-0.3361Stock1 + Stock2)
# At 2015-07-08, short portfolio (-0.3361Stock1 + Stock2)
# At 2015-07-15, close portfolio (-0.3380Stock1 + Stock2)
# At 2015-07-20, long portfolio (-0.3361Stock1 + Stock2)
# At 2015-07-21, close portfolio (-0.3368Stock1 + Stock2)
# At 2015-07-23, short portfolio (-0.3380Stock1 + Stock2)
# At 2015-07-28, close portfolio (-0.3390Stock1 + Stock2)
# At 2015-07-29, short portfolio (-0.3405Stock1 + Stock2)
# At 2015-08-10, close portfolio (-0.3452Stock1 + Stock2)
# At 2015-08-10, long portfolio (-0.3452Stock1 + Stock2)
# At 2015-08-11, close portfolio (-0.3457Stock1 + Stock2)
# At 2015-08-25, long portfolio (-0.3471Stock1 + Stock2)
# At 2015-09-03, close portfolio (-0.3410Stock1 + Stock2)
# At 2015-09-14, long portfolio (-0.3351Stock1 + Stock2)
# At 2015-09-16, close portfolio (-0.3350Stock1 + Stock2)
# At 2015-09-17, short portfolio (-0.3361Stock1 + Stock2)
# At 2015-09-18, close portfolio (-0.3360Stock1 + Stock2)
# At 2015-09-29, short portfolio (-0.3361Stock1 + Stock2)
# At 2015-10-09, close portfolio (-0.3493Stock1 + Stock2)
# At 2015-10-21, long portfolio (-0.3479Stock1 + Stock2)
# At 2015-10-23, close portfolio (-0.3589Stock1 + Stock2)
# At 2015-10-23, short portfolio (-0.3589Stock1 + Stock2)
# At 2015-10-29, close portfolio (-0.3671Stock1 + Stock2)
# At 2015-12-01, short portfolio (-0.3678Stock1 + Stock2)
# At 2016-01-04, close portfolio (-0.3796Stock1 + Stock2)
# At 2016-01-05, short portfolio (-0.3794Stock1 + Stock2)
# At 2016-01-07, close portfolio (-0.3792Stock1 + Stock2)
# At 2016-01-11, long portfolio (-0.3785Stock1 + Stock2)
# At 2016-01-14, close portfolio (-0.3780Stock1 + Stock2)
# At 2016-01-15, long portfolio (-0.3775Stock1 + Stock2)
# At 2016-01-25, close portfolio (-0.3747Stock1 + Stock2)
# At 2016-01-27, short portfolio (-0.3723Stock1 + Stock2)
# At 2016-02-03, close portfolio (-0.3784Stock1 + Stock2)
# At 2016-02-03, long portfolio (-0.3784Stock1 + Stock2)
# At 2016-02-12, close portfolio (-0.3698Stock1 + Stock2)
# At 2016-02-18, short portfolio (-0.3761Stock1 + Stock2)
# At 2016-02-23, close portfolio (-0.3783Stock1 + Stock2)
# At 2016-03-04, long portfolio (-0.3673Stock1 + Stock2)
# At 2016-03-09, close portfolio (-0.3660Stock1 + Stock2)
# At 2016-04-05, long portfolio (-0.3640Stock1 + Stock2)
# At 2016-04-07, close portfolio (-0.3633Stock1 + Stock2)
# At 2016-04-15, short portfolio (-0.3624Stock1 + Stock2)
# At 2016-04-22, close portfolio (-0.3602Stock1 + Stock2)
# At 2016-04-22, long portfolio (-0.3602Stock1 + Stock2)
# At 2016-04-27, close portfolio (-0.3554Stock1 + Stock2)
# At 2016-05-02, short portfolio (-0.3503Stock1 + Stock2)
# At 2016-05-03, close portfolio (-0.3498Stock1 + Stock2)
# At 2016-05-12, short portfolio (-0.3522Stock1 + Stock2)
# At 2016-05-16, close portfolio (-0.3525Stock1 + Stock2)
# At 2016-05-23, long portfolio (-0.3418Stock1 + Stock2)
# At 2016-05-24, close portfolio (-0.3424Stock1 + Stock2)
# At 2016-06-09, long portfolio (-0.3410Stock1 + Stock2)
# At 2016-06-16, close portfolio (-0.3385Stock1 + Stock2)
# At 2016-06-21, short portfolio (-0.3401Stock1 + Stock2)
# At 2016-06-24, close portfolio (-0.3428Stock1 + Stock2)
# At 2016-06-27, long portfolio (-0.3436Stock1 + Stock2)
# At 2016-06-29, close portfolio (-0.3445Stock1 + Stock2)
# At 2016-07-08, short portfolio (-0.3501Stock1 + Stock2)
# At 2016-07-18, close portfolio (-0.3563Stock1 + Stock2)
# At 2016-07-19, long portfolio (-0.3541Stock1 + Stock2)
# At 2016-07-20, close portfolio (-0.3589Stock1 + Stock2)
# At 2016-07-20, short portfolio (-0.3589Stock1 + Stock2)
# At 2016-07-27, close portfolio (-0.3542Stock1 + Stock2)
# At 2016-07-27, long portfolio (-0.3542Stock1 + Stock2)
# At 2016-08-04, close portfolio (-0.3397Stock1 + Stock2)
# At 2016-09-13, long portfolio (-0.3318Stock1 + Stock2)
# At 2016-09-21, close portfolio (-0.3043Stock1 + Stock2)
# At 2016-09-21, short portfolio (-0.3043Stock1 + Stock2)
# At 2016-09-26, close portfolio (-0.3046Stock1 + Stock2)
# At 2016-09-27, short portfolio (-0.3058Stock1 + Stock2)
# At 2016-09-30, close portfolio (-0.3064Stock1 + Stock2)
# At 2016-10-11, long portfolio (-0.3013Stock1 + Stock2)
# At 2016-10-18, close portfolio (-0.2956Stock1 + Stock2)
# At 2016-10-21, short portfolio (-0.2988Stock1 + Stock2)
# At 2016-11-04, close portfolio (-0.3081Stock1 + Stock2)
# At 2016-11-07, short portfolio (-0.3101Stock1 + Stock2)
# At 2016-11-10, close portfolio (-0.3118Stock1 + Stock2)
# At 2016-11-17, short portfolio (-0.3165Stock1 + Stock2)
# At 2016-11-23, close portfolio (-0.3188Stock1 + Stock2)
# At 2016-12-01, long portfolio (-0.3185Stock1 + Stock2)
# At 2016-12-05, close portfolio (-0.3184Stock1 + Stock2)
# At 2016-12-05, short portfolio (-0.3184Stock1 + Stock2)
# At 2016-12-06, close portfolio (-0.3184Stock1 + Stock2)
# At 2016-12-07, short portfolio (-0.3211Stock1 + Stock2)
# At 2016-12-08, close portfolio (-0.3209Stock1 + Stock2)
# At 2016-12-12, short portfolio (-0.3238Stock1 + Stock2)
# At 2016-12-15, close portfolio (-0.3253Stock1 + Stock2)
# At 2016-12-19, short portfolio (-0.3262Stock1 + Stock2)
# At 2016-12-23, close portfolio (-0.3276Stock1 + Stock2)
# At 2016-12-30, long portfolio (-0.3252Stock1 + Stock2)
# At 2017-01-11, close portfolio (-0.3208Stock1 + Stock2)
# At 2017-01-17, long portfolio (-0.3187Stock1 + Stock2)
# At 2017-01-20, close portfolio (-0.3176Stock1 + Stock2)
# At 2017-01-24, short portfolio (-0.3195Stock1 + Stock2)
# At 2017-01-31, close portfolio (-0.3265Stock1 + Stock2)
# At 2017-02-01, long portfolio (-0.3028Stock1 + Stock2)
# At 2017-02-13, close portfolio (-0.2775Stock1 + Stock2)
# At 2017-03-28, long portfolio (-0.2675Stock1 + Stock2)
# At 2017-03-30, close portfolio (-0.2674Stock1 + Stock2)
# At 2017-03-31, short portfolio (-0.2681Stock1 + Stock2)
# At 2017-04-03, close portfolio (-0.2678Stock1 + Stock2)
# At 2017-04-11, short portfolio (-0.2680Stock1 + Stock2)
# At 2017-04-12, close portfolio (-0.2679Stock1 + Stock2)
# At 2017-04-21, short portfolio (-0.2703Stock1 + Stock2)
# At 2017-05-02, close portfolio (-0.2824Stock1 + Stock2)
# At 2017-05-05, long portfolio (-0.2797Stock1 + Stock2)
# At 2017-05-16, close portfolio (-0.2592Stock1 + Stock2)
# At 2017-05-16, short portfolio (-0.2592Stock1 + Stock2)
# At 2017-05-18, close portfolio (-0.2586Stock1 + Stock2)
# At 2017-05-25, short portfolio (-0.2625Stock1 + Stock2)
# At 2017-06-08, close portfolio (-0.2755Stock1 + Stock2)
# At 2017-06-23, short portfolio (-0.2758Stock1 + Stock2)
# At 2017-06-26, close portfolio (-0.2756Stock1 + Stock2)
# At 2017-06-27, long portfolio (-0.2751Stock1 + Stock2)
# At 2017-07-05, close portfolio (-0.2725Stock1 + Stock2)
# At 2017-07-12, short portfolio (-0.2788Stock1 + Stock2)
# At 2017-07-24, close portfolio (-0.2909Stock1 + Stock2)
# At 2017-07-24, long portfolio (-0.2909Stock1 + Stock2)
# At 2017-07-25, close portfolio (-0.2909Stock1 + Stock2)
# At 2017-08-02, long portfolio (-0.2728Stock1 + Stock2)
# At 2017-08-11, close portfolio (-0.2596Stock1 + Stock2)
# At 2017-08-31, short portfolio (-0.2640Stock1 + Stock2)
# At 2017-09-01, close portfolio (-0.2632Stock1 + Stock2)
# At 2017-09-07, short portfolio (-0.2643Stock1 + Stock2)
# At 2017-09-25, close portfolio (-0.2700Stock1 + Stock2)
# At 2017-09-26, long portfolio (-0.2681Stock1 + Stock2)
# At 2017-09-28, close portfolio (-0.2677Stock1 + Stock2)
# At 2017-10-04, short portfolio (-0.2700Stock1 + Stock2)
# At 2017-10-16, close portfolio (-0.2787Stock1 + Stock2)
# At 2017-10-19, short portfolio (-0.2773Stock1 + Stock2)
# At 2017-10-26, close portfolio (-0.2807Stock1 + Stock2)
# At 2017-10-27, short portfolio (-0.2983Stock1 + Stock2)
# At 2017-10-31, close portfolio (-0.2980Stock1 + Stock2)
# At 2017-10-31, long portfolio (-0.2980Stock1 + Stock2)
# At 2017-11-01, close portfolio (-0.2983Stock1 + Stock2)
# At 2017-11-03, long portfolio (-0.2959Stock1 + Stock2)
# At 2017-11-13, close portfolio (-0.2868Stock1 + Stock2)
# At 2017-11-14, short portfolio (-0.2873Stock1 + Stock2)
# At 2017-11-16, close portfolio (-0.2872Stock1 + Stock2)
# At 2017-11-22, long portfolio (-0.2833Stock1 + Stock2)
# At 2017-11-27, close portfolio (-0.2835Stock1 + Stock2)
# At 2017-11-28, short portfolio (-0.2859Stock1 + Stock2)
# At 2017-12-04, close portfolio (-0.2846Stock1 + Stock2)
# At 2017-12-04, long portfolio (-0.2846Stock1 + Stock2)
# At 2017-12-06, close portfolio (-0.2846Stock1 + Stock2)
# At 2017-12-08, short portfolio (-0.2880Stock1 + Stock2)
# At 2017-12-14, close portfolio (-0.2938Stock1 + Stock2)
# At 2017-12-15, short portfolio (-0.2977Stock1 + Stock2)
# At 2017-12-18, close portfolio (-0.2961Stock1 + Stock2)
# At 2017-12-26, short portfolio (-0.2934Stock1 + Stock2)
# At 2018-01-02, close portfolio (-0.2946Stock1 + Stock2)
# At 2018-01-12, short portfolio (-0.3042Stock1 + Stock2)
# At 2018-01-16, close portfolio (-0.3032Stock1 + Stock2)
# At 2018-01-22, short portfolio (-0.3093Stock1 + Stock2)
# At 2018-02-05, close portfolio (-0.3219Stock1 + Stock2)
# At 2018-02-05, long portfolio (-0.3219Stock1 + Stock2)
# At 2018-02-09, close portfolio (-0.3257Stock1 + Stock2)
# At 2018-03-13, long portfolio (-0.3293Stock1 + Stock2)
# At 2018-03-16, close portfolio (-0.3285Stock1 + Stock2)
# At 2018-03-22, long portfolio (-0.3284Stock1 + Stock2)
# At 2018-03-26, close portfolio (-0.3411Stock1 + Stock2)
# At 2018-03-26, short portfolio (-0.3411Stock1 + Stock2)
# At 2018-03-27, close portfolio (-0.3398Stock1 + Stock2)
# At 2018-03-27, long portfolio (-0.3398Stock1 + Stock2)
# At 2018-03-29, close portfolio (-0.3421Stock1 + Stock2)
# At 2018-03-29, short portfolio (-0.3421Stock1 + Stock2)
# At 2018-04-02, close portfolio (-0.3399Stock1 + Stock2)
# At 2018-04-02, long portfolio (-0.3399Stock1 + Stock2)
# At 2018-04-04, close portfolio (-0.3441Stock1 + Stock2)
# At 2018-04-04, short portfolio (-0.3441Stock1 + Stock2)
# At 2018-04-06, close portfolio (-0.3450Stock1 + Stock2)
# At 2018-04-17, short portfolio (-0.3552Stock1 + Stock2)
# At 2018-04-24, close portfolio (-0.3527Stock1 + Stock2)
# At 2018-04-25, long portfolio (-0.3515Stock1 + Stock2)
# At 2018-04-26, close portfolio (-0.3532Stock1 + Stock2)
# At 2018-04-27, short portfolio (-0.3558Stock1 + Stock2)
# At 2018-04-30, close portfolio (-0.3510Stock1 + Stock2)
# At 2018-04-30, long portfolio (-0.3510Stock1 + Stock2)
# At 2018-05-09, close portfolio (-0.2990Stock1 + Stock2)
# At 2018-06-19, short portfolio (-0.3173Stock1 + Stock2)
# At 2018-06-22, close portfolio (-0.3194Stock1 + Stock2)
# At 2018-06-25, long portfolio (-0.3185Stock1 + Stock2)
# At 2018-07-02, close portfolio (-0.3146Stock1 + Stock2)
# At 2018-07-06, short portfolio (-0.3185Stock1 + Stock2)
# At 2018-07-19, close portfolio (-0.3329Stock1 + Stock2)
# At 2018-07-19, long portfolio (-0.3329Stock1 + Stock2)
# At 2018-07-20, close portfolio (-0.3357Stock1 + Stock2)
# At 2018-07-20, short portfolio (-0.3357Stock1 + Stock2)
# At 2018-07-27, close portfolio (-0.3496Stock1 + Stock2)
# At 2018-07-30, long portfolio (-0.3472Stock1 + Stock2)
# At 2018-08-07, close portfolio (-0.3086Stock1 + Stock2)
# At 2018-08-16, long portfolio (-0.3000Stock1 + Stock2)
# At 2018-08-22, close portfolio (-0.2887Stock1 + Stock2)
# At 2018-09-05, long portfolio (-0.2891Stock1 + Stock2)
# At 2018-09-10, close portfolio (-0.2903Stock1 + Stock2)
# At 2018-09-10, short portfolio (-0.2903Stock1 + Stock2)
# At 2018-09-19, close portfolio (-0.3019Stock1 + Stock2)
# At 2018-09-21, short portfolio (-0.3068Stock1 + Stock2)
# At 2018-09-25, close portfolio (-0.3064Stock1 + Stock2)
# At 2018-10-03, long portfolio (-0.2963Stock1 + Stock2)
# At 2018-10-12, close portfolio (-0.2955Stock1 + Stock2)
# At 2018-10-16, short portfolio (-0.3006Stock1 + Stock2)
# At 2018-10-18, close portfolio (-0.3023Stock1 + Stock2)
# At 2018-10-23, long portfolio (-0.2950Stock1 + Stock2)
# At 2018-10-25, close portfolio (-0.2993Stock1 + Stock2)
# At 2018-10-25, short portfolio (-0.2993Stock1 + Stock2)
# At 2018-10-29, close portfolio (-0.2996Stock1 + Stock2)
# At 2018-10-29, long portfolio (-0.2996Stock1 + Stock2)
# At 2018-10-31, close portfolio (-0.3006Stock1 + Stock2)
# At 2018-11-01, long portfolio (-0.2956Stock1 + Stock2)
# At 2018-11-02, close portfolio (-0.2909Stock1 + Stock2)
# At 2018-11-02, short portfolio (-0.2909Stock1 + Stock2)
# At 2018-11-09, close portfolio (-0.3013Stock1 + Stock2)
# At 2018-11-23, short portfolio (-0.3047Stock1 + Stock2)
# At 2018-12-04, close portfolio (-0.3326Stock1 + Stock2)
# At 2018-12-07, long portfolio (-0.3346Stock1 + Stock2)
# At 2018-12-10, close portfolio (-0.3357Stock1 + Stock2)
# At 2018-12-11, short portfolio (-0.3378Stock1 + Stock2)
# At 2018-12-14, close portfolio (-0.3410Stock1 + Stock2)
# At 2018-12-17, long portfolio (-0.3394Stock1 + Stock2)
# At 2018-12-19, close portfolio (-0.3367Stock1 + Stock2)
# At 2018-12-24, long portfolio (-0.3456Stock1 + Stock2)
# At 2018-12-26, close portfolio (-0.3488Stock1 + Stock2)
# At 2019-01-03, short portfolio (-0.3475Stock1 + Stock2)
# At 2019-01-10, close portfolio (-0.3591Stock1 + Stock2)
# At 2019-01-15, short portfolio (-0.3628Stock1 + Stock2)
# At 2019-01-25, close portfolio (-0.3718Stock1 + Stock2)
# At 2019-01-28, long portfolio (-0.3675Stock1 + Stock2)
# At 2019-02-05, close portfolio (-0.3288Stock1 + Stock2)
# At 2019-02-15, short portfolio (-0.3332Stock1 + Stock2)
# At 2019-02-20, close portfolio (-0.3332Stock1 + Stock2)
# At 2019-02-21, short portfolio (-0.3375Stock1 + Stock2)
# At 2019-03-04, close portfolio (-0.3509Stock1 + Stock2)
# At 2019-03-18, short portfolio (-0.3544Stock1 + Stock2)
# DailyVol 0.0057, totRet 0.3245, sharpe 0.8456

# %%
fig, ax = plt.subplots( figsize=(20, 10) )
ax.plot( stratobj.price_df.index[BURNIN:], stratobj.spread_df[BURNIN:] )
ax.set_title( " Daily Vol {:.2f}%, TotRet {:.2f}%, Sharpe {:.2f}".format(
               stratobj.dailyVol*100, stratobj.totRet*100, stratobj.sharpe ),
               fontsize=20 )
direction = []; timeline = []; spread = []; accVal = []
for tt, sigs in stratobj.sigseq.seq.items():
    for sig in sigs:
        timeline.append( datetime.datetime.strptime(tt, "%Y-%m-%d") )
        direction.append( sig.direction )
        spread.append( stratobj.spread_df[tt] )
        accVal.append( stratobj.accVal[tt] )
for idx, action in enumerate(direction):
    if action == 0:
        direction[idx] = - direction[idx-1]
        
ax.scatter(np.array(timeline)[np.array(direction) == 1],
           np.array(spread)[np.array(direction) == 1] ,
           c='g', marker="^", label="BuySignal", s=100)
ax.scatter(np.array(timeline)[np.array(direction) == -1],
           np.array(spread)[np.array(direction) == -1],
           c='r', marker="^", label="SellSignal", s=100)
ax.legend()

fig, ax = plt.subplots( figsize=(20, 10) )
ax.plot( stratobj.price_df.index[BURNIN:], stratobj.accVal/stratobj.accVal.iloc[0] )
ax.scatter(np.array(timeline)[np.array(direction) == 1],
           np.array(accVal/stratobj.accVal.iloc[0])[np.array(direction) == 1],
           c='g', marker="^", label="BuySignal", s=100)
ax.scatter(np.array(timeline)[np.array(direction) == -1],
           np.array(accVal/stratobj.accVal.iloc[0])[np.array(direction) == -1],
           c='r', marker="^", label="SellSignal", s=100)

ax.set_title( " Daily Vol {:.2f}%, TotRet {:.2f}%, Sharpe {:.2f}".format(
               stratobj.dailyVol*100, stratobj.totRet*100, stratobj.sharpe ),
               fontsize=20 )
ax.legend()
plt.show()
